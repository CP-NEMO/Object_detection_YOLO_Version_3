# %%
import os
from os.path import exists, join, basename, splitext
import matplotlib.pyplot as plt


git_repo_url = 'https://github.com/CP-NEMO/Object_detection_YOLO_Version_3'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt
  
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
if not exists('yolov3.weights'):
  # !wget -q https://drive.google.com/file/d/1I92QB0ifKoEOZcUq6gAfay-o4Tjw1xTU/view?usp=sharing

# %%
IMAGE_URL = 'https://i.postimg.cc/02pvdYwM/ancient-architecture-buildings-1583704.jpg'


image_file = basename(IMAGE_URL)
# !wget -q -O $image_file $IMAGE_URL
plt.figure(figsize=(15, 15))
plt.imshow(matplotlib.image.imread(image_file))

# %%
# !cd Object_detection_YOLO_Version_3 && python detect.py --weights ../yolov3.weights --images ../$image_file --det ..

plt.figure(figsize=(15, 15))
plt.imshow(matplotlib.image.imread('det_%s' % image_file))
# Out:
# Loading network.....
# Network successfully loaded
# ancient-architecture-buildings-1583704.jpg predicted in  1.123 seconds
# Objects Detected:    person person person person person person person person person person person person person person person car car car truck clock
# ----------------------------------------------------------
#
# SUMMARY
# ----------------------------------------------------------
# Task                     : Time Taken (in seconds)
#
# Reading addresses        : 0.000
# Loading batch            : 1.343
# Detection (1 images)     : 1.126
# Output Processing        : 0.000
# Drawing Boxes            : 0.016
# Average time_per_img     : 2.485
# ----------------------------------------------------------
